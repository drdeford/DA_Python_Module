# %% [markdown]
# # Introduction
#
# This week we are focusing on conditional expressions in two settings. First, we will use extensions of the comparison operators we talked about in week 2 to slice dataframes to extract relevant subsets. Then, we will explore the use of if/else flow control operators to create more complex scripts.
#
# The readings for this week are:
#
# * [Sections 5.1-5.7 of Think Python](https://greenteapress.com/thinkpython2/html/thinkpython2006.html)
# * [Chapter 8 of Problem Solving with Python](https://problemsolvingwithpython.com/08-If-Else-Try-Except/08.00-Introduction/)

# %% [markdown]
# In our investigation of the college rankings data in the last notebook, we saw some outliers that suggested we might want to investigate them more carefully. Something that we will frequently want to do is select subsets of data that satisfy certain properties. For this, we can use the comparison operators, combined with the `.loc` syntax we've used before. In fact, we actually did this several times with the equality (`==`) operator in the previous notebook when we were extracting schools by type or by state. More description of ways to slice dataframes can be found in the [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
College_Rankings = pd.read_csv("../Week7_Plotting2/Data/College_Rankings.csv")

# %%
College_Rankings.loc[College_Rankings["Grad4"]<20]
# Out:
#      Rank                                               Name State    Type  \
# 128   129  California State University, Long Beach, Long ...    CA  Public
# 428   129  California State University, Long Beach, Long ...    CA  Public
#
#      Admit  Grad4   Cost  NeedAid  NonNeedAid  NNApercent  GradDebt  Salary  \
# 128     36     15  25768     6538        2356          17     16579   46900
# 428     35     15  25030     6549        2356          17     17058   47320
#
#      Year
# 128  2019
# 428  2021

# %%
College_Rankings["Cost"]<60000
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 570     True
# 571     True
# 572     True
# 573     True
# 574     True
# 575    False
# 576     True
# 577     True
# 578     True
# 579     True
# 580    False
# 581     True
# 582     True
# 583     True
# 584     True
# 585     True
# 586     True
# 587    False
# 588     True
# 589     True
# 590     True
# 591     True
# 592     True
# 593     True
# 594     True
# 595     True
# 596     True
# 597     True
# 598     True
# 599     True
# Name: Cost, Length: 600, dtype: bool

# %%
College_Rankings.loc[College_Rankings["Admit"] < 10]
# Out:
#      Rank                                              Name State     Type  \
# 1       2                   Princeton University, Princeton    NJ  Private
# 2       3                     Harvard University, Cambridge    MA  Private
# 8       9                        Yale University, New Haven    CT  Private
# 14     15      California Institute of Technology, Pasadena    CA  Private
# 16     17  Massachusetts Institute of Technology, Cambridge    MA  Private
# 20     21                     Stanford University, Stanford    CA  Private
# 30     31                      Brown University, Providence    RI  Private
# 301     2                   Princeton University, Princeton    NJ  Private
# 302     3                     Harvard University, Cambridge    MA  Private
# 308     9                        Yale University, New Haven    CT  Private
# 310    11                           Duke University, Durham    NC  Private
# 316    17  Massachusetts Institute of Technology, Cambridge    MA  Private
# 320    21                     Stanford University, Stanford    CA  Private
# 330    31                      Brown University, Providence    RI  Private
# 332    33          University of Pennsylvania, Philadelphia    PA  Private
#
#      Admit  Grad4   Cost  NeedAid  NonNeedAid  NNApercent  GradDebt  Salary  \
# 1        7     90  58660    42097           0           0      6600   75100
# 2        6     86  61659    44430       20827           0     15117   87200
# 8        6     87  63250    45710           0           0     14853   66000
# 14       9     85  60084    37557           0           0     12104   74000
# 16       8     81  61434    37090           0           0     19064   91600
# 20       5     76  61852    41620        8980           0     19230   80900
# 30       9     85  63496    40917        9452           0     24300   59700
# 301      7     93  58911    42009           0           0      6511   75090
# 302      7     89  61019    44521       20827           0     15406   87227
# 308      8     83  62838    45808           0           0     15382   65317
# 310      9     85  65347    41873       20714          21     19932   76103
# 316      8     80  60896    37087           0           0     19243   91420
# 320      5     75  61062    41646        8980           0     18700   81606
# 330      9     83  62692    40862        9452           0     23602   59818
# 332      9     82  65289    40044           0           0     20005   77788
#
#      Year
# 1    2019
# 2    2019
# 8    2019
# 14   2019
# 16   2019
# 20   2019
# 30   2019
# 301  2021
# 302  2021
# 308  2021
# 310  2021
# 316  2021
# 320  2020
# 330  2020
# 332  2021

# %%
College_Rankings.loc[College_Rankings["Grad4"] >= 90]
# Out:
#      Rank                                           Name State          Type  \
# 1       2                Princeton University, Princeton    NJ       Private
# 3       4                     Davidson College, Davidson    NC  Liberal Arts
# 7       8                      Pomona College, Claremont    CA  Liberal Arts
# 18     19                   Colgate University, Hamilton    NY  Liberal Arts
# 29     30                   Carleton College, Northfield    MN  Liberal Arts
# 45     46           University of Notre Dame, Notre Dame    IN       Private
# 46     47              Georgetown University, Washington    DC       Private
# 47     48           College of the Holy Cross, Worcester    MA  Liberal Arts
# 49     50                 Harvey Mudd College, Claremont    CA  Liberal Arts
# 56     57  Washington University in St. Louis, St. Louis    MO       Private
# 301     2                Princeton University, Princeton    NJ       Private
# 303     4                     Davidson College, Davidson    NC  Liberal Arts
# 311    12                        Kenyon College, Gambier    OH  Liberal Arts
# 312    13                 Williams College, Williamstown    MA  Liberal Arts
# 314    15   California Institute of Technology, Pasadena    CA       Private
# 319    20                       Amherst College, Amherst    MA  Liberal Arts
# 325    26                   Haverford College, Haverford    PA  Liberal Arts
# 329    30                   Carleton College, Northfield    MN  Liberal Arts
# 334    35                     Cornell University, Ithaca    NY       Private
# 345    46           University of Notre Dame, Notre Dame    IN       Private
# 346    47              Georgetown University, Washington    DC       Private
# 347    48           College of the Holy Cross, Worcester    MA  Liberal Arts
# 349    50                 Harvey Mudd College, Claremont    CA  Liberal Arts
# 352    53            Johns Hopkins University, Baltimore    MD       Private
# 353    54                  Boston College, Chestnut Hill    MA       Private
# 356    57  Washington University in St. Louis, St. Louis    MO       Private
# 358    59                      Lafayette College, Easton    PA  Liberal Arts
# 371    72             Skidmore College, Saratoga Springs    NY  Liberal Arts
#
#      Admit  Grad4   Cost  NeedAid  NonNeedAid  NNApercent  GradDebt  Salary  \
# 1        7     90  58660    42097           0           0      6600   75100
# 3       22     90  61119    37170       23834          15     22000   58500
# 7       12     90  63670    41443           0           0     16273   52600
# 18      26     90  63580    41428           0           0     21405   61500
# 29      23     91  62846    34050        3095          15     18302   46100
# 45      21     90  62825    33025       15804          12     26674   69400
# 46      17     91  64385    36878           0           0     22464   83300
# 47      43     90  60624    32207       33808           4     28354   63700
# 49      14     90  68055    35637       10546          46     24503   78600
# 56      17     90  64350    35555        8665          18     23858   62300
# 301      7     93  58911    42009           0           0      6511   75090
# 303     21     92  61427    37207       23834          15     21351   58600
# 311     25     90  62505    38013       13311          22     20604   44255
# 312     20     92  63234    43650           0           0     14422   58742
# 314     10     90  60254    37540           0           0     11813   73367
# 319     16     90  65697    47326           0           0     13786   57033
# 325     23     93  65719    42552           0           0     15371   56497
# 329     21     93  63659    33985        3095          15     18407   46042
# 334     12     90  62792    37604           0           0     21233   71241
# 345     23     93  62208    32942       15804          12     27401   69245
# 346     19     93  64981    36967           0           0     22877   82347
# 347     42     91  61359    32165       33808           4     28607   62862
# 349     13     94  67405    35546       10546          46     24275   79321
# 352     16     90  65693    34449       30165           3     23901   68263
# 353     32     92  64686    34639       19189           3     20460   67098
# 356     15     90  65341    35639        8665          18     23845   62431
# 358     31     90  63479    35405       23469          13     27185   69368
# 371     39     90  62693    38495       12000           1     22609   43656
#
#      Year
# 1    2019
# 3    2019
# 7    2019
# 18   2019
# 29   2019
# 45   2019
# 46   2019
# 47   2019
# 49   2019
# 56   2019
# 301  2021
# 303  2020
# 311  2020
# 312  2020
# 314  2021
# 319  2020
# 325  2020
# 329  2020
# 334  2020
# 345  2021
# 346  2020
# 347  2020
# 349  2020
# 352  2021
# 353  2021
# 356  2020
# 358  2020
# 371  2020

# %%
College_Rankings.loc[(College_Rankings["Grad4"] >= 90) & (College_Rankings["Admit"] < 10)]
# Out:
#      Rank                             Name State     Type  Admit  Grad4  \
# 1       2  Princeton University, Princeton    NJ  Private      7     90
# 301     2  Princeton University, Princeton    NJ  Private      7     93
#
#       Cost  NeedAid  NonNeedAid  NNApercent  GradDebt  Salary  Year
# 1    58660    42097           0           0      6600   75100  2019
# 301  58911    42009           0           0      6511   75090  2021

# %%
College_Rankings.loc[(College_Rankings["State"] == "CA") & (College_Rankings["Salary"] < 20000)]
# Out:
#      Rank                                 Name State          Type  Admit  \
# 21     22  Thomas Aquinas College, Santa Paula    CA  Liberal Arts     83
# 321    22  Thomas Aquinas College, Santa Paula    CA  Liberal Arts     83
#
#      Grad4   Cost  NeedAid  NonNeedAid  NNApercent  GradDebt  Salary  Year
# 21      63  32500    15755           0           0     16263       0  2019
# 321     66  31760    15841           0           0     16024    -390  2021

# %%
College_Rankings.loc[College_Rankings["Year"]==2021].loc[(College_Rankings["State"].isin(["WA","OR","ID"])) & (College_Rankings["Salary"] > 50000)]
# Out:
#      Rank                               Name State     Type  Admit  Grad4  \
# 404   105  University of Washington, Seattle    WA   Public     56     60
# 467   168   University of Portland, Portland    OR  Private     61     71
#
#       Cost  NeedAid  NonNeedAid  NNApercent  GradDebt  Salary  Year
# 404  46295    14956        5500           5     21308   52997  2021
# 467  52210    21962       14965          83     25889   50827  2021

# %% [markdown]
# Conditional expressions can also be used to ask python to perform different operations depending on the type of data that it is evaluating. This is our first example of flow control in a python script, where we will ask python to perform different tasks depending on whether a specific statement is True or False.
#
# The main syntax for selection statements consists of a function, an expression that evaluates to True or False followed by a colon, and an indented code block that is to be executed if the expression is True. Try running the cell below and then changing the value to make the expression true. How does the output change?

# %%
a_number = 12

if a_number < 10:
    print('This is a single digit number!')

# %%
your_name = "Margaret"

if len(your_name) > 5:
    print("You have a long name!")
    
else:
    print("You have a short name!")
# Out:
# You have a long name!

# %%
a_new_number = -7

if a_new_number > 0: 
    print("This is a positive number!")
    
elif a_new_number == 0:
    print("Zero is boring!")
    
else: 
    print("This is a negative number!")
# Out:
# This is a negative number!

# %%
your_number = 3.6

if your_number - int(your_number) >=.5:
    your_number = int(your_number) + 1
    
else:
    your_number = int(your_number)
    
print(f"I rounded your number to: {your_number}")
# Out:
# I rounded your number to: 4

# %%
row_number = 100

if College_Rankings.iloc[row_number]["Name"] == "Washington State University":
    print("Go Cougs!")
elif College_Rankings.iloc[row_number]["Name"] == "Somewhere Less Exciting":
    print("We already checked that one!")
else:
    print("meh")
    College_Rankings.at[row_number,"Name"] = "Somewhere Less Exciting"
# Out:
# We already checked that one!
